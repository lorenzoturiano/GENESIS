# %%
import pandas as pd
import numpy as np

# %%
path = "/project/Wellcome_Discovery/datashare/lturiano/GENESIS/data/erythroid/"
df = pd.read_csv(path+"GSM8150512_BM_Normal_RNA.csv.gz", index_col=0)

# %%
df.shape # why just 397 genes?
# Out:
# (2276, 397)

# %%
df.to_numpy().max()
# Out:
# np.int64(10504)
