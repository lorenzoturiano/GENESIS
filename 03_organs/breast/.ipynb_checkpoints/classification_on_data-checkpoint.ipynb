# %%
import scanpy as sc
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import xgboost

# %%
np.random.seed(42)

# %%
# path = "/project/Wellcome_Discovery/datashare/sriva/GENESIS/"
path = "data/retina/"

# %%
rna = sc.read_h5ad(path+"retina_sc_filt.h5ad")
gex = sc.read_h5ad(path+"retina_sn_filt.h5ad")
fake = sc.read_h5ad(path+"retina_Fake_RNA_VAE_UNET_log_norm.h5ad")

# %%
marker_genes = {
    "retinal cone cell": [
        "ARR3", "GNAT2", "PDE6C", "CNGA3", "CNGB3", "OPN1SW"
        # optional if present: "OPN1LW", "OPN1MW"
    ],
    "amacrine cell": [
        "GAD1", "GAD2", "SLC6A1", "TFAP2A", "TFAP2B", "PAX6"
        # optional: "SLC18A2" (some amacrines), "CHAT" (starburst subtype)
    ],
    "Mueller cell": [
        "RLBP1", "GLUL", "SLC1A3", "VIM", "SOX9", "AQP4"
    ],
    "retinal ganglion cell": [
        "RBPMS", "SNCG", "POU4F1", "POU4F2", "NEFL", "NEFM"
    ],
    "retinal rod cell": [
        "RHO", "GNAT1", "PDE6A", "PDE6B", "NRL", "SAG", "CNGA1"
    ],
    "astrocyte": [
        "GFAP", "ALDH1L1", "AQP4", "SLC1A3", "SOX9"
    ],
    "retina horizontal cell": [
        "PROX1", "ONECUT1", "ONECUT2", "LHX1"
    ],
}

# %%
genes = []

for row in list(marker_genes.values()):
    for item in row:
        if item not in genes:
            genes.append(item)
            
np.random.shuffle(genes)

# %%
df_rna = pd.DataFrame(index   = rna.obs.index,
                      columns = genes,
                      data    = rna.X[:, rna.var.feature_name.isin(genes)])

df_gex = pd.DataFrame(index   = gex.obs.index,
                      columns = genes,
                      data    = gex.X[:, gex.var.feature_name.isin(genes)])

df_fake = pd.DataFrame(index   = fake.obs.index,
                       columns = genes,
                       data    = fake.X[:, fake.var.feature_name.isin(genes)])

# %%
# Encode labels
label_encoder = LabelEncoder()
label_encoder.fit(rna.obs["cell_type"].values.tolist())
label_encoder.classes_
# Out:
# array(['Mueller cell', 'amacrine cell', 'astrocyte',
#        'retina horizontal cell', 'retinal cone cell',
#        'retinal ganglion cell', 'retinal rod cell'], dtype='<U22')

# %%
df_rna["cell_type"]  = label_encoder.transform(rna.obs["cell_type"].values.tolist())
df_gex["cell_type"]  = label_encoder.transform(gex.obs["cell_type"].values.tolist())
df_fake["cell_type"] = label_encoder.transform(rna.obs["cell_type"].values.tolist())

# %%
# Create train-test split (final evaluation set)
X_train_rna, X_test_rna, y_train_rna, y_test_rna = train_test_split(df_rna[df_rna.columns[:-1]],
                                                                    df_rna[df_rna.columns[-1]],
                                                                    test_size=0.15,
                                                                    random_state=42,
                                                                    stratify=df_rna[df_rna.columns[-1]]
                                                                    )

# %%
# Create train-test split (final evaluation set)
X_train_gex, X_test_gex, y_train_gex, y_test_gex = train_test_split(df_gex[df_gex.columns[:-1]],
                                                                    df_gex[df_gex.columns[-1]],
                                                                    test_size=0.15,
                                                                    random_state=42,
                                                                    stratify=df_gex[df_gex.columns[-1]]
                                                                    )

# %%
# Create train-test split (final evaluation set)
X_train_fake, X_test_fake, y_train_fake, y_test_fake = train_test_split(df_fake[df_fake.columns[:-1]],
                                                                        df_fake[df_fake.columns[-1]],
                                                                        test_size=0.15,
                                                                        random_state=42,
                                                                        stratify=df_fake[df_fake.columns[-1]]
                                                                        )

# %% [markdown]
# # Training and hyperparameter setting xgboost on scRNA

# %%
# Define XGBoost classifier
xgb_clf = xgboost.XGBClassifier(objective='multi:softprob',
                             num_class=len(label_encoder.classes_),
                             device="cpu",
                             random_state=42)

# %%
# Hyperparameter grid
param_grid = {'booster': ['gbtree', 'dart'],
              'max_depth': [2, 4, 6],
              'learning_rate': [0.01, 0.05, 0.1],
              'n_estimators': [50, 100, 150],
              'subsample': [0.6, 0.8, 1.0],
              }

# %%
# Cross-validation and hyperparameter tuning
clf_cv = GridSearchCV(estimator=xgb_clf,
                      param_grid=param_grid,
                      scoring='accuracy',
                      cv=5,
                      verbose=1,
                      n_jobs=8)

clf_cv.fit(X_train_rna, y_train_rna)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:25] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:25] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:45:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device='cpu',
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learni...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None, num_class=7,
#                                      num_parallel_tree=None, ...),
#              n_jobs=8,
#              param_grid={'booster': ['gbtree', 'dart'],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [2, 4, 6], 'n_estimators': [50, 100, 150],
#                          'subsample': [0.6, 0.8, 1.0]},
#              scoring='accuracy', verbose=1)

# %%
# Best hyperparameters
print("Best hyperparameters:")
print(clf_cv.best_params_)

# Evaluate on final test set
best_model = clf_cv.best_estimator_
# Out:
# Best hyperparameters:
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 150, 'subsample': 0.6}

# %%
# Best hyperparameters:
# {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 150, 'subsample': 0.6}

# %%
best_model.save_model('retina_best_xgb_model.json')

# %% [markdown]
# # Performance evaluation on scRNA, scGEX, generated scGEX

# %%
model_rna = xgboost.XGBClassifier()
model_rna.load_model('retina_best_xgb_model.json')

# %%
# y_pred_rna = model_rna.predict(X_train_rna)
# print(f'Accuracy: {accuracy_score(y_train_rna.values, y_pred_rna):.4f}')

# %%
y_pred_rna = model_rna.predict(X_test_rna)
print(f'Accuracy: {accuracy_score(y_test_rna.values, y_pred_rna):.4f}')
# Out:
# Accuracy: 0.9817

# %%
y_pred_gex = model_rna.predict(X_test_gex)
print(f'Accuracy: {accuracy_score(y_test_gex.values, y_pred_gex):.4f}')
# Out:
# Accuracy: 0.1308

# %%
y_pred_fake = best_model.predict(X_test_fake)
print(f'Accuracy: {accuracy_score(y_test_fake, y_pred_fake):.4f}')
# Out:
# Accuracy: 0.3080

# %% [markdown]
# # Fine-tuning on scGEX

# %%
model_gex = xgboost.XGBClassifier()
model_gex.load_model('retina_best_xgb_model.json')

# %%
model_gex.fit(X_train_gex, 
              y_train_gex,
              xgb_model=model_gex.get_booster(),  # Continue training from existing model
              verbose=True
              )
# Out:
# [16:47:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None,
#               feature_types=['float', 'float', 'float', 'float', 'float',
#                              'float', 'float', 'float', 'float', 'float',
#                              'float', 'float', 'float', 'float', 'float',
#                              'flo...
#                              'float', 'float', 'float', 'float', 'float', ...],
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=150, n_jobs=None, num_class=7,
#               num_parallel_tree=None, ...)

# %%
y_pred_rna = model_gex.predict(X_test_rna)
print(f'Accuracy: {accuracy_score(y_test_rna.values, y_pred_rna):.4f}')
# Out:
# Accuracy: 0.6920

# %%
y_pred_gex = model_gex.predict(X_test_gex)
print(f'Accuracy: {accuracy_score(y_test_gex.values, y_pred_gex):.4f}')
# Out:
# Accuracy: 0.9612

# %%
y_pred_fake = model_gex.predict(X_test_fake)
print(f'Accuracy: {accuracy_score(y_test_fake, y_pred_fake):.4f}')
# Out:
# Accuracy: 0.1445

# %% [markdown]
# # Fine-tuning on generated scRNA

# %%
model_fake = xgboost.XGBClassifier()
model_fake.load_model('retina_best_xgb_model.json')

# %%
model_fake.fit(X_train_fake, 
               y_train_fake,
               xgb_model=model_fake.get_booster(),  # Continue training from existing model
               verbose=True
               )
# Out:
# [16:48:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None,
#               feature_types=['float', 'float', 'float', 'float', 'float',
#                              'float', 'float', 'float', 'float', 'float',
#                              'float', 'float', 'float', 'float', 'float',
#                              'flo...
#                              'float', 'float', 'float', 'float', 'float', ...],
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=150, n_jobs=None, num_class=7,
#               num_parallel_tree=None, ...)

# %%
y_pred_rna = model_fake.predict(X_test_rna)
print(f'Accuracy: {accuracy_score(y_test_rna.values, y_pred_rna):.4f}')
# Out:
# Accuracy: 0.8433

# %%
y_pred_gex = model_fake.predict(X_test_gex)
print(f'Accuracy: {accuracy_score(y_test_gex.values, y_pred_gex):.4f}')
# Out:
# Accuracy: 0.1027

# %%
y_pred_fake = model_fake.predict(X_test_fake)
print(f'Accuracy: {accuracy_score(y_test_fake, y_pred_fake):.4f}')
# Out:
# Accuracy: 0.9810
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:13] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:15] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:27] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:25] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:34] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:02] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:07] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:25] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:09] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:37] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:31] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
#
# [16:43:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:41:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:17] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:41] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:31:59] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:14] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:35] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:40] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:44] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:32:57] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:01] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:21] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:32] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:33:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:00] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:34:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:12] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:35:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:10] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:38] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:36:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:23] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:37:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:38:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:11] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:39:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:40:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:16] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:22] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:25] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:28] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:30] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:33] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:36] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:49] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:41:58] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:39] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:42] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:53] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:04] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:26] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:50] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:54] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:19] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
# [16:42:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:03] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:24] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:48] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:56] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:46] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
#
# [16:42:45] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:42:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:06] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:29] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:52] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:05] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:18] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:43] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
#
# [16:43:51] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:43:55] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:20] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
#
# [16:44:47] WARNING: ../src/learner.cc:767:
# Parameters: { "device" } are not used.
